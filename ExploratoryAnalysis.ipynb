# %% [markdown]
# ## SUMMARY

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = 50
df = pd.read_excel('2023_wc_all_pbp.xlsx')
# Display the first few rows of the dataset
df.head(10)
# Out:
#    Unnamed: 0  ListIndex      AC  \
# 0           1          0  STARTG
# 1           2          1      JB
# 2           3          2      JB
# 3           4          3    FOUL
# 4           5          4   RFOUL
# 5           6          5     TTO
# 6           7          6      P2
# 7           8          7     REB
# 8           9          8      P3
# 9          10          9     ASS
#
#                                              Action       Id  SA  SB  \
# 0                                     START of Game   0:0002   0   0
# 1                                     Jump ball won   2:0012   0   0
# 2                                    Jump ball lost  2:0012B   0   0
# 3                             Personal foul (P1,T1)   2:0013   0   0
# 4                                        Foul drawn   2:0014   0   0
# 5                     Team Turnover, 24 seconds (1)   2:0015   0   0
# 6  2PtsFG inside paint, Turnaround Jump Shot missed   2:0016   0   0
# ...

# %%
# Display basic information about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44086 entries, 0 to 44085
# Data columns (total 47 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         44086 non-null  int64
#  1   ListIndex          44086 non-null  int64
#  2   AC                 44086 non-null  object
#  3   Action             44086 non-null  object
#  4   Id                 44086 non-null  object
#  5   SA                 44086 non-null  int64
#  6   SB                 44086 non-null  int64
#  7   Time               44086 non-null  object
#  8   game_mins          44086 non-null  int64
#  9   game_seconds       44086 non-null  int64
#  10  game_milliseconds  0 non-null      float64
#  11  GT                 44086 non-null  int64
#  12  Z1                 24915 non-null  object
#  13  Z2                 8981 non-null   object
#  14  Z3                 13071 non-null  object
#  15  C1                 41374 non-null  object
# ...

# %%
# Display summary statistics
print(df.describe())
# Out:
#         Unnamed: 0     ListIndex            SA            SB     game_mins  \
# count  44086.00000  44086.000000  44086.000000  44086.000000  44086.000000
# mean   22043.50000     59.710430     42.933267     43.132741      4.306152
# std    12726.67632     35.655634     25.953450     26.035078      2.929960
# min        1.00000      0.000000      0.000000      0.000000      0.000000
# 25%    11022.25000     29.000000     21.000000     21.000000      2.000000
# 50%    22043.50000     59.000000     42.000000     42.000000      4.000000
# 75%    33064.75000     89.000000     63.000000     63.000000      7.000000
# max    44086.00000    160.000000    118.000000    128.000000     10.000000
#
#        game_seconds  game_milliseconds            GT            SP  \
# count  44086.000000                0.0  4.408600e+04  25821.000000
# mean      28.119607                NaN  1.693447e+12      2.263003
# std       17.771264                NaN  3.549394e+08      1.688285
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Unnamed: 0               0
# ListIndex                0
# AC                       0
# Action                   0
# Id                       0
# SA                       0
# SB                       0
# Time                     0
# game_mins                0
# game_seconds             0
# game_milliseconds    44086
# GT                       0
# Z1                   19171
# Z2                   35105
# Z3                   31015
# C1                    2712
# SU                   28217
# T1                     740
# PId                  32122
# SP                   18265
# ST                   18107
# STQ                  18107
# STQS                 29012
# STS                  29012
# SX                   32172
# SY                   32172
# SPS                  29866
# Score                35833
# C2                   39618
# name                  2712
# Nationality           2712
# ID                    2712
# ParentId              2712
# Position              2712
# ...

# %%
df.group.value_counts()
# Out:
# group
# Group C    3023
# Group A    2954
# Group B    2914
# Group F    2863
# Group E    2853
# Group G    2821
# Group D    2803
# Group H    2781
# Group N    2043
# Group M    2033
# Group K    1933
# Group O    1912
# Group L    1910
# Group J    1903
# Group P    1856
# Group I    1825
# Name: count, dtype: int64

# %%
df.phase.value_counts()
# Out:
# phase
# First Round                   23012
# Classification Round 17-32     7844
# Second Round                   7571
# Quarter-Finals                 1842
# Semi-Finals                     948
# Class. Games 5-8                896
# 3rd Place Game                  574
# Class. Games 7-8                479
# Class. Games 5-6                470
# Final                           450
# Name: count, dtype: int64

# %%
df.groupby('Nationality').size()
# Out:
# Nationality
# ANG    1222
# AUS    1178
# BRA    1135
# CAN    1878
# CHN    1070
# CIV    1041
# CPV    1126
# DOM    1145
# EGY    1188
# ESP    1198
# FIN    1189
# FRA    1098
# GEO    1116
# GER    1763
# GRE    1044
# IRI    1044
# ITA    1770
# JOR    1099
# JPN    1054
# LAT    1696
# LBN    1029
# LTU    1807
# MEX    1079
# MNE    1104
# NZL    1246
# PHI    1133
# PUR    1146
# SLO    1817
# SRB    1780
# SSD    1172
# USA    1965
# VEN    1042
# dtype: int64

# %% [markdown]
# ## Creating Boxscore Stats for one game

# %%
from boxscore_utils import create_boxscore_one_game

# %% [markdown]
# addind new columns

# %%
rsc = '25276-H-3'
game1 = df[df.rsc==rsc]
create_boxscore_one_game(game1)

# %% [markdown]
# ## HOW TO WIN?
# analyzing Germany Team

# %%
df_germany = df[df.Nationality == 'GER']
df_germany
# Out:
#        Unnamed: 0  ListIndex     AC                                   Action  \
# 3948         3949          1     JB                            Jump ball won
# 3951         3952          4  RFOUL                               Foul drawn
# 3952         3953          5     P2  2PtsFG inside paint, Layup made (2 Pts)
# 3953         3954          6    ASS                               Assist (1)
# 3955         3956          8    REB                    Defensive rebound (1)
# ...           ...        ...    ...                                      ...
# 44078       44079        122  RFOUL                               Foul drawn
# 44079       44080        123  SUBST                             Substitution
# 44080       44081        124     FT          Free Throw made 1 of 2 (27 Pts)
# 44081       44082        125     FT          Free Throw made 2 of 2 (28 Pts)
# 44084       44085        128  SUBST                             Substitution
#
# ...

# %% [markdown]
# Team Players

# %%
df_germany[['name',	'Position',	'Age',	'Height']].drop_duplicates()
# Out:
#                      name Position   Age  Height
# 3948         Daniel THEIS       PF  31.0   203.0
# 3951   Johannes VOIGTMANN        C  30.0   211.0
# 3952      Dennis SCHRODER       PG  29.0   185.0
# 3953          Isaac BONGA       PG  23.0   203.0
# 3965         Andreas OBST       SG  27.0   191.0
# 3998             Maodo LO       PG  30.0   191.0
# 4005         Niels GIFFEY       SF  32.0   200.0
# 4006        Moritz WAGNER        F  26.0   211.0
# 4007    Johannes THIEMANN       PF  29.0   205.0
# 4034       Justus HOLLATZ       PG  22.0   191.0
# 13886        David KRAMER       PG  26.0   196.0
# 29488        Franz WAGNER        G  22.0   208.0
